# %%
# 모듈 import

from mmcv import Config
from mmdet.datasets import build_dataset
from mmdet.models import build_detector
from mmdet.apis import train_detector
from mmdet.datasets import (build_dataloader, build_dataset,
                            replace_ImageToTensor)
from mmdet.utils import get_device

# %%
classes = ("General trash", "Paper", "Paper pack", "Metal", "Glass", 
           "Plastic", "Styrofoam", "Plastic bag", "Battery", "Clothing")

# config file 들고오기
cfg = Config.fromfile('./configs/faster_rcnn/faster_rcnn_r50_fpn_1x_coco.py')

root='../../dataset/'

# dataset config 수정
cfg.data.train.classes = classes
cfg.data.train.img_prefix = root
cfg.data.train.ann_file = root + 'train.json' # train json 정보
cfg.data.train.pipeline[2]['img_scale'] = (512,512) # Resize

cfg.data.test.classes = classes
cfg.data.test.img_prefix = root
cfg.data.test.ann_file = root + 'test.json' # test json 정보
cfg.data.test.pipeline[1]['img_scale'] = (512,512) # Resize

cfg.data.samples_per_gpu = 4

cfg.seed = 2022
cfg.gpu_ids = [0]
cfg.work_dir = './work_dirs/faster_rcnn_r50_fpn_1x_trash'

cfg.model.roi_head.bbox_head.num_classes = 10

cfg.optimizer_config.grad_clip = dict(max_norm=35, norm_type=2)
cfg.checkpoint_config = dict(max_keep_ckpts=3, interval=1)
cfg.device = get_device()

# %%
# build_dataset
datasets = [build_dataset(cfg.data.train)]
# Out:
# loading annotations into memory...
# Done (t=0.08s)
# creating index...
# index created!

# %%
# dataset 확인
datasets[0]
# Out:
# CocoDataset Train dataset with number of images 4883, and instance counts:
# +-------------------+-------+---------------+-------+-----------------+-------+-------------+-------+--------------+-------+
# | category          | count | category      | count | category        | count | category    | count | category     | count |
# +-------------------+-------+---------------+-------+-----------------+-------+-------------+-------+--------------+-------+
# | 0 [General trash] | 3965  | 1 [Paper]     | 6352  | 2 [Paper pack]  | 897   | 3 [Metal]   | 936   | 4 [Glass]    | 982   |
# | 5 [Plastic]       | 2943  | 6 [Styrofoam] | 1263  | 7 [Plastic bag] | 5178  | 8 [Battery] | 159   | 9 [Clothing] | 468   |
# +-------------------+-------+---------------+-------+-----------------+-------+-------------+-------+--------------+-------+

# %%
# 모델 build 및 pretrained network 불러오기
model = build_detector(cfg.model)
model.init_weights()
# Out:
# 2023-05-07 07:45:24,729 - mmcv - INFO - initialize ResNet with init_cfg {'type': 'Pretrained', 'checkpoint': 'torchvision://resnet50'}
# 2023-05-07 07:45:24,730 - mmcv - INFO - load model from: torchvision://resnet50
# 2023-05-07 07:45:24,731 - mmcv - INFO - load checkpoint from torchvision path: torchvision://resnet50
# 2023-05-07 07:45:24,978 - mmcv - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 2023-05-07 07:45:25,001 - mmcv - INFO - initialize FPN with init_cfg {'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
# 2023-05-07 07:45:25,028 - mmcv - INFO - initialize RPNHead with init_cfg {'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01}
# 2023-05-07 07:45:25,036 - mmcv - INFO - initialize Shared2FCBBoxHead with init_cfg [{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'distribution': 'uniform', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
# 2023-05-07 07:45:25,142 - mmcv - INFO -
# backbone.conv1.weight - torch.Size([64, 3, 7, 7]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,143 - mmcv - INFO -
# backbone.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,144 - mmcv - INFO -
# backbone.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,145 - mmcv - INFO -
# backbone.layer1.0.conv1.weight - torch.Size([64, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,145 - mmcv - INFO -
# backbone.layer1.0.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,146 - mmcv - INFO -
# backbone.layer1.0.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,146 - mmcv - INFO -
# backbone.layer1.0.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,147 - mmcv - INFO -
# backbone.layer1.0.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,147 - mmcv - INFO -
# backbone.layer1.0.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,148 - mmcv - INFO -
# backbone.layer1.0.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,149 - mmcv - INFO -
# backbone.layer1.0.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,150 - mmcv - INFO -
# backbone.layer1.0.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,150 - mmcv - INFO -
# backbone.layer1.0.downsample.0.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,151 - mmcv - INFO -
# backbone.layer1.0.downsample.1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,151 - mmcv - INFO -
# backbone.layer1.0.downsample.1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,152 - mmcv - INFO -
# backbone.layer1.1.conv1.weight - torch.Size([64, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,153 - mmcv - INFO -
# backbone.layer1.1.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,153 - mmcv - INFO -
# backbone.layer1.1.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,154 - mmcv - INFO -
# backbone.layer1.1.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,154 - mmcv - INFO -
# backbone.layer1.1.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,155 - mmcv - INFO -
# backbone.layer1.1.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,155 - mmcv - INFO -
# backbone.layer1.1.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,156 - mmcv - INFO -
# backbone.layer1.1.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,156 - mmcv - INFO -
# backbone.layer1.1.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,157 - mmcv - INFO -
# backbone.layer1.2.conv1.weight - torch.Size([64, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,157 - mmcv - INFO -
# backbone.layer1.2.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,158 - mmcv - INFO -
# backbone.layer1.2.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,158 - mmcv - INFO -
# backbone.layer1.2.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,159 - mmcv - INFO -
# backbone.layer1.2.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,159 - mmcv - INFO -
# backbone.layer1.2.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,160 - mmcv - INFO -
# backbone.layer1.2.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,160 - mmcv - INFO -
# backbone.layer1.2.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,163 - mmcv - INFO -
# backbone.layer1.2.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,164 - mmcv - INFO -
# backbone.layer2.0.conv1.weight - torch.Size([128, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,165 - mmcv - INFO -
# backbone.layer2.0.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,165 - mmcv - INFO -
# backbone.layer2.0.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,166 - mmcv - INFO -
# backbone.layer2.0.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,166 - mmcv - INFO -
# backbone.layer2.0.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,167 - mmcv - INFO -
# backbone.layer2.0.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,168 - mmcv - INFO -
# backbone.layer2.0.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,168 - mmcv - INFO -
# backbone.layer2.0.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,169 - mmcv - INFO -
# backbone.layer2.0.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,169 - mmcv - INFO -
# backbone.layer2.0.downsample.0.weight - torch.Size([512, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,170 - mmcv - INFO -
# backbone.layer2.0.downsample.1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,170 - mmcv - INFO -
# backbone.layer2.0.downsample.1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,171 - mmcv - INFO -
# backbone.layer2.1.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,171 - mmcv - INFO -
# backbone.layer2.1.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,172 - mmcv - INFO -
# backbone.layer2.1.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,173 - mmcv - INFO -
# backbone.layer2.1.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,173 - mmcv - INFO -
# backbone.layer2.1.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,174 - mmcv - INFO -
# backbone.layer2.1.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,174 - mmcv - INFO -
# backbone.layer2.1.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,175 - mmcv - INFO -
# backbone.layer2.1.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,175 - mmcv - INFO -
# backbone.layer2.1.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,176 - mmcv - INFO -
# backbone.layer2.2.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,176 - mmcv - INFO -
# backbone.layer2.2.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,177 - mmcv - INFO -
# backbone.layer2.2.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,177 - mmcv - INFO -
# backbone.layer2.2.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,178 - mmcv - INFO -
# backbone.layer2.2.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,178 - mmcv - INFO -
# backbone.layer2.2.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,179 - mmcv - INFO -
# backbone.layer2.2.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,180 - mmcv - INFO -
# backbone.layer2.2.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,180 - mmcv - INFO -
# backbone.layer2.2.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,181 - mmcv - INFO -
# backbone.layer2.3.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,181 - mmcv - INFO -
# backbone.layer2.3.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,182 - mmcv - INFO -
# backbone.layer2.3.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,182 - mmcv - INFO -
# backbone.layer2.3.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,183 - mmcv - INFO -
# backbone.layer2.3.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,183 - mmcv - INFO -
# backbone.layer2.3.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,184 - mmcv - INFO -
# backbone.layer2.3.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,184 - mmcv - INFO -
# backbone.layer2.3.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,185 - mmcv - INFO -
# backbone.layer2.3.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,185 - mmcv - INFO -
# backbone.layer3.0.conv1.weight - torch.Size([256, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,186 - mmcv - INFO -
# backbone.layer3.0.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,186 - mmcv - INFO -
# backbone.layer3.0.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,187 - mmcv - INFO -
# backbone.layer3.0.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,188 - mmcv - INFO -
# backbone.layer3.0.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,188 - mmcv - INFO -
# backbone.layer3.0.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,189 - mmcv - INFO -
# backbone.layer3.0.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,189 - mmcv - INFO -
# backbone.layer3.0.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,190 - mmcv - INFO -
# backbone.layer3.0.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,190 - mmcv - INFO -
# backbone.layer3.0.downsample.0.weight - torch.Size([1024, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,191 - mmcv - INFO -
# backbone.layer3.0.downsample.1.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,191 - mmcv - INFO -
# backbone.layer3.0.downsample.1.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,192 - mmcv - INFO -
# backbone.layer3.1.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,193 - mmcv - INFO -
# backbone.layer3.1.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,193 - mmcv - INFO -
# backbone.layer3.1.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,194 - mmcv - INFO -
# backbone.layer3.1.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,194 - mmcv - INFO -
# backbone.layer3.1.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,195 - mmcv - INFO -
# backbone.layer3.1.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,195 - mmcv - INFO -
# backbone.layer3.1.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,196 - mmcv - INFO -
# backbone.layer3.1.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,197 - mmcv - INFO -
# backbone.layer3.1.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,199 - mmcv - INFO -
# backbone.layer3.2.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,200 - mmcv - INFO -
# backbone.layer3.2.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,200 - mmcv - INFO -
# backbone.layer3.2.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,201 - mmcv - INFO -
# backbone.layer3.2.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,201 - mmcv - INFO -
# backbone.layer3.2.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,202 - mmcv - INFO -
# backbone.layer3.2.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,202 - mmcv - INFO -
# backbone.layer3.2.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,203 - mmcv - INFO -
# backbone.layer3.2.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,203 - mmcv - INFO -
# backbone.layer3.2.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,204 - mmcv - INFO -
# backbone.layer3.3.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,205 - mmcv - INFO -
# backbone.layer3.3.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,205 - mmcv - INFO -
# backbone.layer3.3.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,206 - mmcv - INFO -
# backbone.layer3.3.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,206 - mmcv - INFO -
# backbone.layer3.3.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,207 - mmcv - INFO -
# backbone.layer3.3.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,207 - mmcv - INFO -
# backbone.layer3.3.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,208 - mmcv - INFO -
# backbone.layer3.3.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,208 - mmcv - INFO -
# backbone.layer3.3.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,209 - mmcv - INFO -
# backbone.layer3.4.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,209 - mmcv - INFO -
# backbone.layer3.4.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,210 - mmcv - INFO -
# backbone.layer3.4.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,210 - mmcv - INFO -
# backbone.layer3.4.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,211 - mmcv - INFO -
# backbone.layer3.4.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,212 - mmcv - INFO -
# backbone.layer3.4.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,212 - mmcv - INFO -
# backbone.layer3.4.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,213 - mmcv - INFO -
# backbone.layer3.4.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,213 - mmcv - INFO -
# backbone.layer3.4.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,214 - mmcv - INFO -
# backbone.layer3.5.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,214 - mmcv - INFO -
# backbone.layer3.5.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,215 - mmcv - INFO -
# backbone.layer3.5.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,215 - mmcv - INFO -
# backbone.layer3.5.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,216 - mmcv - INFO -
# backbone.layer3.5.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,217 - mmcv - INFO -
# backbone.layer3.5.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,217 - mmcv - INFO -
# backbone.layer3.5.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,218 - mmcv - INFO -
# backbone.layer3.5.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,218 - mmcv - INFO -
# backbone.layer3.5.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,219 - mmcv - INFO -
# backbone.layer4.0.conv1.weight - torch.Size([512, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,220 - mmcv - INFO -
# backbone.layer4.0.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,220 - mmcv - INFO -
# backbone.layer4.0.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,221 - mmcv - INFO -
# backbone.layer4.0.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,221 - mmcv - INFO -
# backbone.layer4.0.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,222 - mmcv - INFO -
# backbone.layer4.0.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,222 - mmcv - INFO -
# backbone.layer4.0.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,223 - mmcv - INFO -
# backbone.layer4.0.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,223 - mmcv - INFO -
# backbone.layer4.0.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,224 - mmcv - INFO -
# backbone.layer4.0.downsample.0.weight - torch.Size([2048, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,224 - mmcv - INFO -
# backbone.layer4.0.downsample.1.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,225 - mmcv - INFO -
# backbone.layer4.0.downsample.1.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,225 - mmcv - INFO -
# backbone.layer4.1.conv1.weight - torch.Size([512, 2048, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,226 - mmcv - INFO -
# backbone.layer4.1.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,226 - mmcv - INFO -
# backbone.layer4.1.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,227 - mmcv - INFO -
# backbone.layer4.1.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,228 - mmcv - INFO -
# backbone.layer4.1.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,228 - mmcv - INFO -
# backbone.layer4.1.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,229 - mmcv - INFO -
# backbone.layer4.1.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,229 - mmcv - INFO -
# backbone.layer4.1.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,230 - mmcv - INFO -
# backbone.layer4.1.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,230 - mmcv - INFO -
# backbone.layer4.2.conv1.weight - torch.Size([512, 2048, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,231 - mmcv - INFO -
# backbone.layer4.2.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,231 - mmcv - INFO -
# backbone.layer4.2.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,232 - mmcv - INFO -
# backbone.layer4.2.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,232 - mmcv - INFO -
# backbone.layer4.2.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,233 - mmcv - INFO -
# backbone.layer4.2.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,233 - mmcv - INFO -
# backbone.layer4.2.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,234 - mmcv - INFO -
# backbone.layer4.2.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,234 - mmcv - INFO -
# backbone.layer4.2.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-05-07 07:45:25,235 - mmcv - INFO -
# neck.lateral_convs.0.conv.weight - torch.Size([256, 256, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-05-07 07:45:25,235 - mmcv - INFO -
# neck.lateral_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of FasterRCNN
#
# 2023-05-07 07:45:25,236 - mmcv - INFO -
# neck.lateral_convs.1.conv.weight - torch.Size([256, 512, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-05-07 07:45:25,236 - mmcv - INFO -
# neck.lateral_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of FasterRCNN
#
# 2023-05-07 07:45:25,237 - mmcv - INFO -
# neck.lateral_convs.2.conv.weight - torch.Size([256, 1024, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-05-07 07:45:25,237 - mmcv - INFO -
# neck.lateral_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of FasterRCNN
#
# 2023-05-07 07:45:25,237 - mmcv - INFO -
# neck.lateral_convs.3.conv.weight - torch.Size([256, 2048, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-05-07 07:45:25,238 - mmcv - INFO -
# neck.lateral_convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of FasterRCNN
#
# 2023-05-07 07:45:25,238 - mmcv - INFO -
# neck.fpn_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-05-07 07:45:25,239 - mmcv - INFO -
# neck.fpn_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of FasterRCNN
#
# 2023-05-07 07:45:25,239 - mmcv - INFO -
# neck.fpn_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-05-07 07:45:25,240 - mmcv - INFO -
# neck.fpn_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of FasterRCNN
#
# 2023-05-07 07:45:25,240 - mmcv - INFO -
# neck.fpn_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-05-07 07:45:25,241 - mmcv - INFO -
# neck.fpn_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of FasterRCNN
#
# 2023-05-07 07:45:25,241 - mmcv - INFO -
# neck.fpn_convs.3.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-05-07 07:45:25,242 - mmcv - INFO -
# neck.fpn_convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of FasterRCNN
#
# 2023-05-07 07:45:25,242 - mmcv - INFO -
# rpn_head.rpn_conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-05-07 07:45:25,243 - mmcv - INFO -
# rpn_head.rpn_conv.bias - torch.Size([256]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-05-07 07:45:25,243 - mmcv - INFO -
# rpn_head.rpn_cls.weight - torch.Size([3, 256, 1, 1]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-05-07 07:45:25,244 - mmcv - INFO -
# rpn_head.rpn_cls.bias - torch.Size([3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-05-07 07:45:25,244 - mmcv - INFO -
# rpn_head.rpn_reg.weight - torch.Size([12, 256, 1, 1]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-05-07 07:45:25,245 - mmcv - INFO -
# rpn_head.rpn_reg.bias - torch.Size([12]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-05-07 07:45:25,245 - mmcv - INFO -
# roi_head.bbox_head.fc_cls.weight - torch.Size([11, 1024]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-05-07 07:45:25,246 - mmcv - INFO -
# roi_head.bbox_head.fc_cls.bias - torch.Size([11]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-05-07 07:45:25,246 - mmcv - INFO -
# roi_head.bbox_head.fc_reg.weight - torch.Size([40, 1024]):
# NormalInit: mean=0, std=0.001, bias=0
#
# 2023-05-07 07:45:25,247 - mmcv - INFO -
# roi_head.bbox_head.fc_reg.bias - torch.Size([40]):
# NormalInit: mean=0, std=0.001, bias=0
#
# 2023-05-07 07:45:25,247 - mmcv - INFO -
# roi_head.bbox_head.shared_fcs.0.weight - torch.Size([1024, 12544]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-05-07 07:45:25,248 - mmcv - INFO -
# roi_head.bbox_head.shared_fcs.0.bias - torch.Size([1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-05-07 07:45:25,248 - mmcv - INFO -
# roi_head.bbox_head.shared_fcs.1.weight - torch.Size([1024, 1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-05-07 07:45:25,249 - mmcv - INFO -
# roi_head.bbox_head.shared_fcs.1.bias - torch.Size([1024]):
# XavierInit: gain=1, distribution=uniform, bias=0

# %%
# 모델 학습
train_detector(model, datasets[0], cfg, distributed=False, validate=False)
# Out:
# 2023-05-07 07:45:25,538 - mmdet - INFO - Automatic scaling of learning rate (LR) has been disabled.
# 2023-05-07 07:45:25,542 - mmdet - INFO - Start running, host: root@548bdb2194e9, work_dir: /opt/ml/baseline/mmdetection/work_dirs/faster_rcnn_r50_fpn_1x_trash
# 2023-05-07 07:45:25,543 - mmdet - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) StepLrUpdaterHook
# (LOW         ) IterTimerHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# 2023-05-07 07:45:25,544 - mmdet - INFO - workflow: [('train', 1)], max: 12 epochs
# 2023-05-07 07:45:25,544 - mmdet - INFO - Checkpoints will be saved to /opt/ml/baseline/mmdetection/work_dirs/faster_rcnn_r50_fpn_1x_trash by HardDiskBackend.
# 2023-05-07 07:45:39,823 - mmdet - INFO - Epoch [1][50/1221]	lr: 1.978e-03, eta: 1:09:28, time: 0.285, data_time: 0.051, memory: 3987, loss_rpn_cls: 0.4242, loss_rpn_bbox: 0.0542, loss_cls: 0.4908, acc: 95.4307, loss_bbox: 0.0963, loss: 1.0654, grad_norm: 6.8112
# 2023-05-07 07:45:51,876 - mmdet - INFO - Epoch [1][100/1221]	lr: 3.976e-03, eta: 1:03:51, time: 0.241, data_time: 0.007, memory: 3997, loss_rpn_cls: 0.1568, loss_rpn_bbox: 0.0486, loss_cls: 0.3393, acc: 93.6660, loss_bbox: 0.2396, loss: 0.7842, grad_norm: 3.2198
# 2023-05-07 07:46:03,729 - mmdet - INFO - Epoch [1][150/1221]	lr: 5.974e-03, eta: 1:01:31, time: 0.237, data_time: 0.007, memory: 3998, loss_rpn_cls: 0.1169, loss_rpn_bbox: 0.0424, loss_cls: 0.3125, acc: 93.9824, loss_bbox: 0.2309, loss: 0.7026, grad_norm: 2.2675
# 2023-05-07 07:46:15,394 - mmdet - INFO - Epoch [1][200/1221]	lr: 7.972e-03, eta: 1:00:01, time: 0.233, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.1481, loss_rpn_bbox: 0.0500, loss_cls: 0.3634, acc: 92.8291, loss_bbox: 0.2745, loss: 0.8361, grad_norm: 3.1992
# 2023-05-07 07:46:27,303 - mmdet - INFO - Epoch [1][250/1221]	lr: 9.970e-03, eta: 0:59:17, time: 0.238, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.1435, loss_rpn_bbox: 0.0554, loss_cls: 0.3335, acc: 93.6729, loss_bbox: 0.2375, loss: 0.7699, grad_norm: 3.1555
# 2023-05-07 07:46:39,268 - mmdet - INFO - Epoch [1][300/1221]	lr: 1.197e-02, eta: 0:58:46, time: 0.239, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.1512, loss_rpn_bbox: 0.0614, loss_cls: 0.3991, acc: 91.5791, loss_bbox: 0.3137, loss: 0.9254, grad_norm: 2.6057
# 2023-05-07 07:46:50,532 - mmdet - INFO - Epoch [1][350/1221]	lr: 1.397e-02, eta: 0:57:52, time: 0.225, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.1137, loss_rpn_bbox: 0.0470, loss_cls: 0.3310, acc: 92.7676, loss_bbox: 0.2654, loss: 0.7572, grad_norm: 2.4135
# 2023-05-07 07:47:01,976 - mmdet - INFO - Epoch [1][400/1221]	lr: 1.596e-02, eta: 0:57:15, time: 0.229, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.1882, loss_rpn_bbox: 0.0574, loss_cls: 0.4212, acc: 91.9961, loss_bbox: 0.2917, loss: 0.9585, grad_norm: 3.3626
# 2023-05-07 07:47:14,166 - mmdet - INFO - Epoch [1][450/1221]	lr: 1.796e-02, eta: 0:57:07, time: 0.244, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.1586, loss_rpn_bbox: 0.0564, loss_cls: 0.4085, acc: 92.0938, loss_bbox: 0.2717, loss: 0.8951, grad_norm: 2.6283
# 2023-05-07 07:47:26,239 - mmdet - INFO - Epoch [1][500/1221]	lr: 1.996e-02, eta: 0:56:55, time: 0.241, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.1356, loss_rpn_bbox: 0.0549, loss_cls: 0.3672, acc: 92.3809, loss_bbox: 0.2564, loss: 0.8140, grad_norm: 2.3918
# 2023-05-07 07:47:38,215 - mmdet - INFO - Epoch [1][550/1221]	lr: 2.000e-02, eta: 0:56:41, time: 0.240, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.1419, loss_rpn_bbox: 0.0495, loss_cls: 0.3589, acc: 92.3340, loss_bbox: 0.2520, loss: 0.8024, grad_norm: 2.1064
# 2023-05-07 07:47:49,773 - mmdet - INFO - Epoch [1][600/1221]	lr: 2.000e-02, eta: 0:56:17, time: 0.231, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.1048, loss_rpn_bbox: 0.0506, loss_cls: 0.3835, acc: 91.3389, loss_bbox: 0.2793, loss: 0.8182, grad_norm: 1.9507
# 2023-05-07 07:48:01,680 - mmdet - INFO - Epoch [1][650/1221]	lr: 2.000e-02, eta: 0:56:03, time: 0.238, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.1195, loss_rpn_bbox: 0.0491, loss_cls: 0.3673, acc: 91.9658, loss_bbox: 0.2587, loss: 0.7947, grad_norm: 2.0966
# 2023-05-07 07:48:13,749 - mmdet - INFO - Epoch [1][700/1221]	lr: 2.000e-02, eta: 0:55:52, time: 0.241, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.0855, loss_rpn_bbox: 0.0430, loss_cls: 0.3663, acc: 91.8232, loss_bbox: 0.2566, loss: 0.7513, grad_norm: 1.6695
# 2023-05-07 07:48:25,672 - mmdet - INFO - Epoch [1][750/1221]	lr: 2.000e-02, eta: 0:55:38, time: 0.238, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.0786, loss_rpn_bbox: 0.0408, loss_cls: 0.3291, acc: 92.0371, loss_bbox: 0.2437, loss: 0.6922, grad_norm: 1.7922
# 2023-05-07 07:48:37,278 - mmdet - INFO - Epoch [1][800/1221]	lr: 2.000e-02, eta: 0:55:19, time: 0.232, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.0832, loss_rpn_bbox: 0.0374, loss_cls: 0.3226, acc: 92.4004, loss_bbox: 0.2257, loss: 0.6689, grad_norm: 1.7343
# 2023-05-07 07:48:49,429 - mmdet - INFO - Epoch [1][850/1221]	lr: 2.000e-02, eta: 0:55:10, time: 0.243, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.1003, loss_rpn_bbox: 0.0418, loss_cls: 0.3228, acc: 92.5078, loss_bbox: 0.2249, loss: 0.6898, grad_norm: 1.8415
# 2023-05-07 07:49:01,117 - mmdet - INFO - Epoch [1][900/1221]	lr: 2.000e-02, eta: 0:54:53, time: 0.234, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.1062, loss_rpn_bbox: 0.0555, loss_cls: 0.3852, acc: 90.6816, loss_bbox: 0.2802, loss: 0.8272, grad_norm: 2.0053
# 2023-05-07 07:49:12,958 - mmdet - INFO - Epoch [1][950/1221]	lr: 2.000e-02, eta: 0:54:39, time: 0.237, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.1025, loss_rpn_bbox: 0.0463, loss_cls: 0.3601, acc: 91.7607, loss_bbox: 0.2416, loss: 0.7505, grad_norm: 1.9185
# 2023-05-07 07:49:24,899 - mmdet - INFO - Epoch [1][1000/1221]	lr: 2.000e-02, eta: 0:54:27, time: 0.239, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.0865, loss_rpn_bbox: 0.0461, loss_cls: 0.3577, acc: 91.4785, loss_bbox: 0.2578, loss: 0.7481, grad_norm: 1.6761
# 2023-05-07 07:49:36,669 - mmdet - INFO - Epoch [1][1050/1221]	lr: 2.000e-02, eta: 0:54:12, time: 0.235, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.0967, loss_rpn_bbox: 0.0394, loss_cls: 0.3274, acc: 92.4111, loss_bbox: 0.2214, loss: 0.6848, grad_norm: 1.8179
# 2023-05-07 07:49:48,570 - mmdet - INFO - Epoch [1][1100/1221]	lr: 2.000e-02, eta: 0:54:00, time: 0.238, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.0717, loss_rpn_bbox: 0.0402, loss_cls: 0.3650, acc: 90.7891, loss_bbox: 0.2744, loss: 0.7513, grad_norm: 1.5844
# 2023-05-07 07:50:00,676 - mmdet - INFO - Epoch [1][1150/1221]	lr: 2.000e-02, eta: 0:53:50, time: 0.242, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.0825, loss_rpn_bbox: 0.0471, loss_cls: 0.3578, acc: 90.6836, loss_bbox: 0.2772, loss: 0.7646, grad_norm: 1.7485
# 2023-05-07 07:50:12,500 - mmdet - INFO - Epoch [1][1200/1221]	lr: 2.000e-02, eta: 0:53:36, time: 0.236, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.0827, loss_rpn_bbox: 0.0418, loss_cls: 0.3349, acc: 91.5078, loss_bbox: 0.2509, loss: 0.7104, grad_norm: 1.8630
# 2023-05-07 07:50:17,432 - mmdet - INFO - Saving checkpoint at 1 epochs
# 2023-05-07 07:50:32,797 - mmdet - INFO - Epoch [2][50/1221]	lr: 2.000e-02, eta: 0:52:51, time: 0.285, data_time: 0.052, memory: 3999, loss_rpn_cls: 0.0715, loss_rpn_bbox: 0.0396, loss_cls: 0.3249, acc: 91.8672, loss_bbox: 0.2356, loss: 0.6715, grad_norm: 1.6270
# 2023-05-07 07:50:44,778 - mmdet - INFO - Epoch [2][100/1221]	lr: 2.000e-02, eta: 0:52:40, time: 0.240, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.0748, loss_rpn_bbox: 0.0407, loss_cls: 0.3642, acc: 91.0117, loss_bbox: 0.2507, loss: 0.7304, grad_norm: 1.8680
# 2023-05-07 07:50:56,915 - mmdet - INFO - Epoch [2][150/1221]	lr: 2.000e-02, eta: 0:52:31, time: 0.243, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.0862, loss_rpn_bbox: 0.0484, loss_cls: 0.3199, acc: 91.8164, loss_bbox: 0.2325, loss: 0.6870, grad_norm: 1.6389
# 2023-05-07 07:51:08,588 - mmdet - INFO - Epoch [2][200/1221]	lr: 2.000e-02, eta: 0:52:17, time: 0.233, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.0773, loss_rpn_bbox: 0.0415, loss_cls: 0.3414, acc: 91.2090, loss_bbox: 0.2567, loss: 0.7170, grad_norm: 1.7293
# 2023-05-07 07:51:20,342 - mmdet - INFO - Epoch [2][250/1221]	lr: 2.000e-02, eta: 0:52:04, time: 0.235, data_time: 0.006, memory: 3999, loss_rpn_cls: 0.0711, loss_rpn_bbox: 0.0394, loss_cls: 0.3606, acc: 91.0293, loss_bbox: 0.2564, loss: 0.7275, grad_norm: 1.8237
# 2023-05-07 07:51:31,914 - mmdet - INFO - Epoch [2][300/1221]	lr: 2.000e-02, eta: 0:51:50, time: 0.231, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.0566, loss_rpn_bbox: 0.0296, loss_cls: 0.3067, acc: 91.8945, loss_bbox: 0.2227, loss: 0.6157, grad_norm: 1.7402
# 2023-05-07 07:51:43,969 - mmdet - INFO - Epoch [2][350/1221]	lr: 2.000e-02, eta: 0:51:40, time: 0.241, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.0724, loss_rpn_bbox: 0.0458, loss_cls: 0.3700, acc: 90.3369, loss_bbox: 0.2697, loss: 0.7579, grad_norm: 1.8992
# 2023-05-07 07:51:56,319 - mmdet - INFO - Epoch [2][400/1221]	lr: 2.000e-02, eta: 0:51:32, time: 0.247, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.0679, loss_rpn_bbox: 0.0383, loss_cls: 0.3203, acc: 91.8057, loss_bbox: 0.2343, loss: 0.6608, grad_norm: 1.6973
# 2023-05-07 07:52:15,214 - mmdet - INFO - Epoch [2][450/1221]	lr: 2.000e-02, eta: 0:52:15, time: 0.378, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.0772, loss_rpn_bbox: 0.0399, loss_cls: 0.3494, acc: 90.8154, loss_bbox: 0.2671, loss: 0.7336, grad_norm: 1.7817
# 2023-05-07 07:52:36,922 - mmdet - INFO - Epoch [2][500/1221]	lr: 2.000e-02, eta: 0:53:15, time: 0.434, data_time: 0.008, memory: 3999, loss_rpn_cls: 0.0729, loss_rpn_bbox: 0.0328, loss_cls: 0.2819, acc: 92.5361, loss_bbox: 0.2061, loss: 0.5936, grad_norm: 1.6903
# 2023-05-07 07:52:58,682 - mmdet - INFO - Epoch [2][550/1221]	lr: 2.000e-02, eta: 0:54:11, time: 0.435, data_time: 0.008, memory: 3999, loss_rpn_cls: 0.0836, loss_rpn_bbox: 0.0418, loss_cls: 0.3260, acc: 91.8037, loss_bbox: 0.2317, loss: 0.6830, grad_norm: 1.8734
# 2023-05-07 07:53:20,324 - mmdet - INFO - Epoch [2][600/1221]	lr: 2.000e-02, eta: 0:55:02, time: 0.433, data_time: 0.008, memory: 3999, loss_rpn_cls: 0.0741, loss_rpn_bbox: 0.0398, loss_cls: 0.3131, acc: 91.7539, loss_bbox: 0.2371, loss: 0.6641, grad_norm: 1.7432
# 2023-05-07 07:53:41,723 - mmdet - INFO - Epoch [2][650/1221]	lr: 2.000e-02, eta: 0:55:48, time: 0.428, data_time: 0.008, memory: 3999, loss_rpn_cls: 0.0769, loss_rpn_bbox: 0.0366, loss_cls: 0.3167, acc: 91.8496, loss_bbox: 0.2259, loss: 0.6562, grad_norm: 1.6577
# 2023-05-07 07:54:03,348 - mmdet - INFO - Epoch [2][700/1221]	lr: 2.000e-02, eta: 0:56:31, time: 0.432, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.0814, loss_rpn_bbox: 0.0377, loss_cls: 0.3192, acc: 91.7236, loss_bbox: 0.2307, loss: 0.6691, grad_norm: 1.8068
# 2023-05-07 07:54:24,825 - mmdet - INFO - Epoch [2][750/1221]	lr: 2.000e-02, eta: 0:57:10, time: 0.430, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.0652, loss_rpn_bbox: 0.0398, loss_cls: 0.3187, acc: 91.5703, loss_bbox: 0.2376, loss: 0.6612, grad_norm: 1.6355
# 2023-05-07 07:54:46,391 - mmdet - INFO - Epoch [2][800/1221]	lr: 2.000e-02, eta: 0:57:47, time: 0.431, data_time: 0.008, memory: 3999, loss_rpn_cls: 0.0772, loss_rpn_bbox: 0.0398, loss_cls: 0.3520, acc: 90.7920, loss_bbox: 0.2523, loss: 0.7213, grad_norm: 1.7920
# 2023-05-07 07:55:07,835 - mmdet - INFO - Epoch [2][850/1221]	lr: 2.000e-02, eta: 0:58:20, time: 0.429, data_time: 0.008, memory: 3999, loss_rpn_cls: 0.0606, loss_rpn_bbox: 0.0406, loss_cls: 0.3459, acc: 90.7793, loss_bbox: 0.2529, loss: 0.7001, grad_norm: 1.5924
# 2023-05-07 07:55:29,405 - mmdet - INFO - Epoch [2][900/1221]	lr: 2.000e-02, eta: 0:58:51, time: 0.431, data_time: 0.009, memory: 3999, loss_rpn_cls: 0.0578, loss_rpn_bbox: 0.0331, loss_cls: 0.3354, acc: 91.0713, loss_bbox: 0.2429, loss: 0.6692, grad_norm: 1.7975
# 2023-05-07 07:55:50,887 - mmdet - INFO - Epoch [2][950/1221]	lr: 2.000e-02, eta: 0:59:20, time: 0.430, data_time: 0.008, memory: 3999, loss_rpn_cls: 0.0694, loss_rpn_bbox: 0.0383, loss_cls: 0.3060, acc: 91.8447, loss_bbox: 0.2320, loss: 0.6456, grad_norm: 1.7625
# 2023-05-07 07:56:12,328 - mmdet - INFO - Epoch [2][1000/1221]	lr: 2.000e-02, eta: 0:59:46, time: 0.429, data_time: 0.008, memory: 3999, loss_rpn_cls: 0.0634, loss_rpn_bbox: 0.0401, loss_cls: 0.3067, acc: 91.6201, loss_bbox: 0.2336, loss: 0.6437, grad_norm: 1.6984
# 2023-05-07 07:56:34,023 - mmdet - INFO - Epoch [2][1050/1221]	lr: 2.000e-02, eta: 1:00:11, time: 0.434, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.0816, loss_rpn_bbox: 0.0467, loss_cls: 0.3203, acc: 91.1475, loss_bbox: 0.2480, loss: 0.6966, grad_norm: 1.8162
# 2023-05-07 07:56:55,965 - mmdet - INFO - Epoch [2][1100/1221]	lr: 2.000e-02, eta: 1:00:35, time: 0.439, data_time: 0.008, memory: 3999, loss_rpn_cls: 0.0737, loss_rpn_bbox: 0.0459, loss_cls: 0.3286, acc: 91.2363, loss_bbox: 0.2386, loss: 0.6869, grad_norm: 1.8757
# 2023-05-07 07:57:17,052 - mmdet - INFO - Epoch [2][1150/1221]	lr: 2.000e-02, eta: 1:00:54, time: 0.422, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.0700, loss_rpn_bbox: 0.0505, loss_cls: 0.3367, acc: 90.9072, loss_bbox: 0.2572, loss: 0.7145, grad_norm: 1.7225
# 2023-05-07 07:57:38,805 - mmdet - INFO - Epoch [2][1200/1221]	lr: 2.000e-02, eta: 1:01:13, time: 0.435, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.0640, loss_rpn_bbox: 0.0375, loss_cls: 0.2971, acc: 92.2061, loss_bbox: 0.2083, loss: 0.6068, grad_norm: 1.6597
# 2023-05-07 07:57:47,891 - mmdet - INFO - Saving checkpoint at 2 epochs
# 2023-05-07 07:58:12,981 - mmdet - INFO - Epoch [3][50/1221]	lr: 2.000e-02, eta: 1:01:05, time: 0.479, data_time: 0.054, memory: 3999, loss_rpn_cls: 0.0591, loss_rpn_bbox: 0.0420, loss_cls: 0.3327, acc: 91.0312, loss_bbox: 0.2404, loss: 0.6742, grad_norm: 1.8167
# 2023-05-07 07:58:34,748 - mmdet - INFO - Epoch [3][100/1221]	lr: 2.000e-02, eta: 1:01:22, time: 0.435, data_time: 0.009, memory: 3999, loss_rpn_cls: 0.0614, loss_rpn_bbox: 0.0375, loss_cls: 0.3066, acc: 91.5449, loss_bbox: 0.2385, loss: 0.6441, grad_norm: 1.8788
# 2023-05-07 07:58:55,948 - mmdet - INFO - Epoch [3][150/1221]	lr: 2.000e-02, eta: 1:01:34, time: 0.424, data_time: 0.008, memory: 3999, loss_rpn_cls: 0.0495, loss_rpn_bbox: 0.0336, loss_cls: 0.2987, acc: 91.4375, loss_bbox: 0.2313, loss: 0.6132, grad_norm: 1.6873
# 2023-05-07 07:59:17,466 - mmdet - INFO - Epoch [3][200/1221]	lr: 2.000e-02, eta: 1:01:47, time: 0.430, data_time: 0.008, memory: 3999, loss_rpn_cls: 0.0618, loss_rpn_bbox: 0.0446, loss_cls: 0.3004, acc: 91.9727, loss_bbox: 0.2205, loss: 0.6272, grad_norm: 1.8364
# 2023-05-07 07:59:39,186 - mmdet - INFO - Epoch [3][250/1221]	lr: 2.000e-02, eta: 1:02:00, time: 0.434, data_time: 0.008, memory: 3999, loss_rpn_cls: 0.0736, loss_rpn_bbox: 0.0433, loss_cls: 0.3171, acc: 91.4346, loss_bbox: 0.2222, loss: 0.6563, grad_norm: 1.7881
# 2023-05-07 08:00:00,604 - mmdet - INFO - Epoch [3][300/1221]	lr: 2.000e-02, eta: 1:02:10, time: 0.428, data_time: 0.008, memory: 3999, loss_rpn_cls: 0.0570, loss_rpn_bbox: 0.0387, loss_cls: 0.2947, acc: 91.8838, loss_bbox: 0.2188, loss: 0.6091, grad_norm: 1.6446
# 2023-05-07 08:00:22,032 - mmdet - INFO - Epoch [3][350/1221]	lr: 2.000e-02, eta: 1:02:18, time: 0.429, data_time: 0.008, memory: 3999, loss_rpn_cls: 0.0478, loss_rpn_bbox: 0.0329, loss_cls: 0.3015, acc: 91.5557, loss_bbox: 0.2270, loss: 0.6091, grad_norm: 1.7208
# 2023-05-07 08:00:43,477 - mmdet - INFO - Epoch [3][400/1221]	lr: 2.000e-02, eta: 1:02:26, time: 0.429, data_time: 0.008, memory: 3999, loss_rpn_cls: 0.0640, loss_rpn_bbox: 0.0405, loss_cls: 0.3231, acc: 91.1836, loss_bbox: 0.2422, loss: 0.6698, grad_norm: 1.8077
# 2023-05-07 08:00:59,119 - mmdet - INFO - Epoch [3][450/1221]	lr: 2.000e-02, eta: 1:02:09, time: 0.313, data_time: 0.008, memory: 3999, loss_rpn_cls: 0.0479, loss_rpn_bbox: 0.0286, loss_cls: 0.2899, acc: 92.0967, loss_bbox: 0.2073, loss: 0.5737, grad_norm: 1.7252
# 2023-05-07 08:01:20,863 - mmdet - INFO - Epoch [3][500/1221]	lr: 2.000e-02, eta: 1:02:17, time: 0.435, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.0618, loss_rpn_bbox: 0.0424, loss_cls: 0.3374, acc: 90.8730, loss_bbox: 0.2549, loss: 0.6965, grad_norm: 1.7722
# 2023-05-07 08:01:42,449 - mmdet - INFO - Epoch [3][550/1221]	lr: 2.000e-02, eta: 1:02:23, time: 0.432, data_time: 0.008, memory: 3999, loss_rpn_cls: 0.0492, loss_rpn_bbox: 0.0331, loss_cls: 0.3131, acc: 91.5752, loss_bbox: 0.2341, loss: 0.6295, grad_norm: 1.6819
# 2023-05-07 08:02:03,988 - mmdet - INFO - Epoch [3][600/1221]	lr: 2.000e-02, eta: 1:02:28, time: 0.431, data_time: 0.007, memory: 3999, loss_rpn_cls: 0.0702, loss_rpn_bbox: 0.0448, loss_cls: 0.3379, acc: 90.3623, loss_bbox: 0.2733, loss: 0.7262, grad_norm: 1.8272
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_25831/1783380618.py in <module>
#       1 # 모델 학습
# ----> 2 train_detector(model, datasets[0], cfg, distributed=False, validate=False)
#
# ~/baseline/mmdetection/mmdet/apis/train.py in train_detector(model, dataset, cfg, distributed, validate, timestamp, meta)
#     242     elif cfg.load_from:
#     243         runner.load_checkpoint(cfg.load_from)
# --> 244     runner.run(data_loaders, cfg.workflow)
#
# /opt/conda/envs/detection/lib/python3.7/site-packages/mmcv/runner/epoch_based_runner.py in run(self, data_loaders, workflow, max_epochs, **kwargs)
#     134                     if mode == 'train' and self.epoch >= self._max_epochs:
#     135                         break
# --> 136                     epoch_runner(data_loaders[i], **kwargs)
#     137
#     138         time.sleep(1)  # wait for some hooks like loggers to finish
#
# /opt/conda/envs/detection/lib/python3.7/site-packages/mmcv/runner/epoch_based_runner.py in train(self, data_loader, **kwargs)
#      51             self._inner_iter = i
#      52             self.call_hook('before_train_iter')
# ---> 53             self.run_iter(data_batch, train_mode=True, **kwargs)
#      54             self.call_hook('after_train_iter')
#      55             del self.data_batch
#
# /opt/conda/envs/detection/lib/python3.7/site-packages/mmcv/runner/epoch_based_runner.py in run_iter(self, data_batch, train_mode, **kwargs)
#      30         elif train_mode:
#      31             outputs = self.model.train_step(data_batch, self.optimizer,
# ---> 32                                             **kwargs)
#      33         else:
#      34             outputs = self.model.val_step(data_batch, self.optimizer, **kwargs)
#
# /opt/conda/envs/detection/lib/python3.7/site-packages/mmcv/parallel/data_parallel.py in train_step(self, *inputs, **kwargs)
#      75
#      76         inputs, kwargs = self.scatter(inputs, kwargs, self.device_ids)
# ---> 77         return self.module.train_step(*inputs[0], **kwargs[0])
#      78
#      79     def val_step(self, *inputs, **kwargs):
#
# ~/baseline/mmdetection/mmdet/models/detectors/base.py in train_step(self, data, optimizer)
#     246                   averaging the logs.
#     247         """
# --> 248         losses = self(**data)
#     249         loss, log_vars = self._parse_losses(losses)
#     250
#
# /opt/conda/envs/detection/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /opt/conda/envs/detection/lib/python3.7/site-packages/mmcv/runner/fp16_utils.py in new_func(*args, **kwargs)
#     117                                 f'method of those classes {supported_types}')
#     118             if not (hasattr(args[0], 'fp16_enabled') and args[0].fp16_enabled):
# --> 119                 return old_func(*args, **kwargs)
#     120
#     121             # get the arg spec of the decorated method
#
# ~/baseline/mmdetection/mmdet/models/detectors/base.py in forward(self, img, img_metas, return_loss, **kwargs)
#     170
#     171         if return_loss:
# --> 172             return self.forward_train(img, img_metas, **kwargs)
#     173         else:
#     174             return self.forward_test(img, img_metas, **kwargs)
#
# ~/baseline/mmdetection/mmdet/models/detectors/two_stage.py in forward_train(self, img, img_metas, gt_bboxes, gt_labels, gt_bboxes_ignore, gt_masks, proposals, **kwargs)
#     148                                                  gt_bboxes, gt_labels,
#     149                                                  gt_bboxes_ignore, gt_masks,
# --> 150                                                  **kwargs)
#     151         losses.update(roi_losses)
#     152
#
# ~/baseline/mmdetection/mmdet/models/roi_heads/standard_roi_head.py in forward_train(self, x, img_metas, proposal_list, gt_bboxes, gt_labels, gt_bboxes_ignore, gt_masks, **kwargs)
#      90                 assign_result = self.bbox_assigner.assign(
#      91                     proposal_list[i], gt_bboxes[i], gt_bboxes_ignore[i],
# ---> 92                     gt_labels[i])
#      93                 sampling_result = self.bbox_sampler.sample(
#      94                     assign_result,
#
# ~/baseline/mmdetection/mmdet/core/bbox/assigners/max_iou_assigner.py in assign(self, bboxes, gt_bboxes, gt_bboxes_ignore, gt_labels)
#     109                 gt_labels = gt_labels.cpu()
#     110
# --> 111         overlaps = self.iou_calculator(gt_bboxes, bboxes)
#     112
#     113         if (self.ignore_iof_thr > 0 and gt_bboxes_ignore is not None
#
# ~/baseline/mmdetection/mmdet/core/bbox/iou_calculators/iou2d_calculator.py in __call__(self, bboxes1, bboxes2, mode, is_aligned)
#      63             return overlaps
#      64
# ---> 65         return bbox_overlaps(bboxes1, bboxes2, mode, is_aligned)
#      66
#      67     def __repr__(self):
#
# ~/baseline/mmdetection/mmdet/core/bbox/iou_calculators/iou2d_calculator.py in bbox_overlaps(bboxes1, bboxes2, mode, is_aligned, eps)
#     248                                     bboxes2[..., None, :, 2:])
#     249
# --> 250     eps = union.new_tensor([eps])
#     251     union = torch.max(union, eps)
#     252     ious = overlap / union
#
# KeyboardInterrupt:
